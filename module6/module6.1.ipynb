# %%
import pandas as pd
import numpy as np 
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
fantasy = movies[movies['genres'].str.contains('Fantasy', case = False)]['genres']
len(fantasy)
# Out:
# 654

# %%
joined = ratings.merge(movies,on='movieId',how='left')
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres
# 0                             Drama
# 1  Animation|Children|Drama|Musical
# 2                          Thriller
# 3  Action|Adventure|Sci-Fi|Thriller
# 4                             Drama

# %%
len(ratings) == len(joined)
# Out:
# True

# %%
direct = pd.read_table('direct_stats.tsv')
crm = pd.read_table('crm_stats.tsv')
crm.head()
# Out:
#          date                 campaign  orders
# 0  2018-01-01           landings_promo    1487
# 1  2018-01-01       homepage_partner_1     386
# 2  2018-01-01       homepage_partner_2     315
# 3  2018-01-01  socdem_w_25-34_vip_test      85
# 4  2018-01-02           landings_promo    1605

# %%
direct.head()
# Out:
#          date                 campaign     views  clicks     cost
# 0  2018-01-01           landings_promo  38120423   49557  1139801
# 1  2018-01-01       homepage_partner_1   5729483   12605   189073
# 2  2018-01-01       homepage_partner_2   4412029    9265   176040
# 3  2018-01-01  socdem_w_25-34_vip_test    913823    2559    89555
# 4  2018-01-02           landings_promo  40873806   61311  1471457

# %%
crmdir = direct.merge(crm,on=['campaign','date'],how='left')

# %%
crmdir.head()
# Out:
#          date                 campaign     views  clicks     cost  orders
# 0  2018-01-01           landings_promo  38120423   49557  1139801    1487
# 1  2018-01-01       homepage_partner_1   5729483   12605   189073     386
# 2  2018-01-01       homepage_partner_2   4412029    9265   176040     315
# 3  2018-01-01  socdem_w_25-34_vip_test    913823    2559    89555      85
# 4  2018-01-02           landings_promo  40873806   61311  1471457    1605

# %%
len(direct)==len(crmdir)
# Out:
# True

# %%
crmdir['costs'] = crmdir['cost']/crmdir['orders']

# %%
crmdir
# Out:
#           date                 campaign     views  clicks     cost  orders  \
# 0   2018-01-01           landings_promo  38120423   49557  1139801    1487
# 1   2018-01-01       homepage_partner_1   5729483   12605   189073     386
# 2   2018-01-01       homepage_partner_2   4412029    9265   176040     315
# 3   2018-01-01  socdem_w_25-34_vip_test    913823    2559    89555      85
# 4   2018-01-02           landings_promo  40873806   61311  1471457    1605
# 5   2018-01-02       homepage_partner_1   6848702   13697   232856     398
# 6   2018-01-02       homepage_partner_2   4855040   11652   174781     354
# 7   2018-01-02  socdem_w_25-34_vip_test   1036158    3212   105999      82
# 8   2018-01-03           landings_promo  42380998   46619  1025620    1576
# 9   2018-01-03       homepage_partner_1   7576118   15152   166675     474
# 10  2018-01-03       homepage_partner_2   5088701   11195   185839     369
# ...
